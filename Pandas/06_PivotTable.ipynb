# %% [markdown]
# # Pivot Table

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    980     29   John  January      Q1
# 1  2023-01-02       B   West    723     75   Mary  January      Q1
# 2  2023-01-03       C  North    658     23    Bob  January      Q1
# 3  2023-01-04       D  South    790     65  Alice  January      Q1
# 4  2023-01-05       A   East    910     37   John  January      Q1
# 5  2023-01-06       B   West    316     52   Mary  January      Q1
# 6  2023-01-07       C  North    825     32    Bob  January      Q1
# 7  2023-01-08       D  South    600     25  Alice  January      Q1
# 8  2023-01-09       A   East    422     63   John  January      Q1
# 9  2023-01-10       B   West    609     24   Mary  January      Q1
# 10 2023-01-11       C  North    248     59    Bob  January      Q1
# 11 2023-01-12       D  South    274     25  Alice  January      Q1
# 12 2023-01-13       A   East    568     21   John  January      Q1
# 13 2023-01-14       B   West    864     35   Mary  January      Q1
# 14 2023-01-15       C  North    522     49    Bob  January      Q1
# 15 2023-01-16       D  South    262     17  Alice  January      Q1
# 16 2023-01-17       A   East    534     23   John  January      Q1
# 17 2023-01-18       B   West    213     45   Mary  January      Q1
# 18 2023-01-19       C  North    194     67    Bob  January      Q1
# 19 2023-01-20       D  South    536     19  Alice  January      Q1

# %%
pd.pivot_table(df, values = "Sales", index = ["Region"], columns = ["Product"])
# Out:
# Product      A      B      C      D
# Region
# East     682.8    NaN    NaN    NaN
# North      NaN    NaN  489.4    NaN
# South      NaN    NaN    NaN  492.4
# West       NaN  545.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values = ["Sales", "Units"], index = ["Region"], columns = ["Product"])
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     682.8    NaN    NaN    NaN  34.6   NaN   NaN   NaN
# North      NaN    NaN  489.4    NaN   NaN   NaN  46.0   NaN
# South      NaN    NaN    NaN  492.4   NaN   NaN   NaN  30.2
# West       NaN  545.0    NaN    NaN   NaN  46.2   NaN   NaN

# %% [markdown]
# ### CrossTab

# %%
pd.crosstab(df["Region"], df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
